# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/asaf/Workspace/biu/complex-utterance-to-code/notebooks

# %%
df = pd.read_csv('../build/train_complex_utterance_to_code_with_intermediate_4k_2.csv.gz')
df
# Out:
#                                                 text
# 0  see if find my first reminders that I have a m...  \
# 1  create a reminder at mindnight to close the wi...
# 2  show route to my office from Northern Mariana ...
# 3  show me how long will it take me to arrive to ...
#
#                                                 code
# 0  person_reminded = Contact.resolve_from_text("m...  \
# 1  date_time = DateTime.resolve_from_text("mindni...
# 2  origin = Location.resolve_from_text("from Nort...
# 3  destinations = Location.resolve_many_from_text...
#
#                                             lang_rep
# 0  [ root\n\t[ S\n\t\t[ Command\n\t\t\t[ Action\n...  \
# 1  [ root\n\t[ S\n\t\t[ Command\n\t\t\t[ Action\n...
# 2  [ root\n\t[ S\n\t\t[ Command\n\t\t\t[ Conditio...
# 3  [ root\n\t[ S\n\t\t[ Command\n\t\t\t[ Action\n...
#
#                                         lang_rep_raw
# 0  [ root\n\t[ hd\n\t\t[ see ]\n\t]\n\t[ advcl\n\...  \
# ...

# %%
print(df['lang_rep_raw'][0])
# Out:
# [ root
# 	[ hd
# 		[ see ]
# 	]
# 	[ advcl
# 		[ mark
# 			[ if ]
# 		]
# 		[ hd
# 			[ find ]
# 		]
# 		[ obj
# 			[ nmod:poss
# 				[ my ]
# 			]
# 			[ amod
# 				[ first ]
# 			]
# 			[ hd
# 				[ reminders ]
# 			]
# 		]
# 		[ ccomp
# 			[ mark
# 				[ that ]
# 			]
# 			[ nsubj
# 				[ I ]
# 			]
# 			[ hd
# 				[ have ]
# 			]
# 			[ obj
# 				[ det
# 					[ a ]
# 				]
# 				[ hd
# 					[ meeting ]
# 				]
# 				[ nmod
# 					[ case
# 						[ at ]
# 					]
# 					[ hd
# 						[ 3 ]
# 					]
# 					[ nmod:tmod
# 						[ pm ]
# 					]
# 				]
# 			]
# 			[ conj
# 				[ cc
# 					[ and ]
# 				]
# 				[ expl
# 					[ there ]
# 				]
# 				[ hd
# 					[ are ]
# 				]
# 				[ conj
# 					[ cc
# 						[ and ]
# 					]
# 					[ hd
# 						[ see ]
# 					]
# 				]
# 				[ advcl
# 					[ mark
# 						[ if ]
# 					]
# 					[ nsubj
# 						[ I ]
# 					]
# 					[ hd
# 						[ got ]
# 					]
# 					[ obj
# 						[ det
# 							[ a ]
# 						]
# 						[ hd
# 							[ reminder ]
# ...

# %%
print(df['lang_rep'][0])
# Out:
# [ root
# 	[ S
# 		[ Command
# 			[ Action
# 				[ hd
# 					[ see ]
# 				]
# 				[ advcl
# 					[ mark
# 						[ if ]
# 					]
# 					[ Command
# 						[ Action
# 							[ hd
# 								[ find ]
# 							]
# 							[ Arg
# 								[ obj
# 									[ nmod:poss
# 										[ my ]
# 									]
# 									[ amod
# 										[ first ]
# 									]
# 									[ hd
# 										[ reminders ]
# 									]
# 								]
# 							]
# 							[ mark
# 								[ that ]
# 							]
# 							[ ccomp
# 								[ Command
# 									[ Action
# 										[ Arg
# 											[ nsubj
# 												[ I ]
# 											]
# 										]
# 										[ hd
# 											[ have ]
# 										]
# 										[ Arg
# 											[ obj
# 												[ det
# 													[ a ]
# 												]
# 												[ hd
# 													[ meeting ]
# 												]
# 												[ nmod
# 													[ case
# 														[ at ]
# 													]
# 													[ hd
# 														[ 3 ]
# 													]
# 													[ nmod:tmod
# ...

# %%
print(df['code_rep'][0])
# Out:
# 	[ Module
# 		[ person_reminded = Contact.resolve_from_text('my') ]
# 		[ content = Content.resolve_from_text('I have a meeting at 3pm') ]
# 		[ reminders = Reminders.find_reminders(person_reminded=person_reminded, content=content) ]
# 		[ reminders = first(reminders) ]
# 		[ Responder.respond(response=reminders) ]
# 		[ test_reminders = bool(reminders) ]
# 		[ Responder.respond(response=test_reminders) ]
# 		[ person_reminded = Contact.resolve_from_text('I') ]
# 		[ date_time = DateTime.resolve_from_text('mindnight in 2 days') ]
# 		[ content = Content.resolve_from_text('bring the keys') ]
# 		[ reminders = Reminders.find_reminders(person_reminded=person_reminded, date_time=date_time, content=content) ]
# 		[ test_reminders = bool(reminders) ]
# 		[ Responder.respond(response=test_reminders) ]
# 	]

# %%
print(df['code_rep_raw'][0])
# Out:
# 	[ Module
# 		[ Assign
# 			[ Name
# 				[ person_reminded ]
# 			]
# 			[ Call
# 				[ func
# 					[ Attribute
# 						[ Name
# 							[ Contact ]
# 						]
# 						[ resolve_from_text ]
# 					]
# 				]
# 				[ arg
# 					[ Constant
# 						[ str
# 							[ my ]
# 						]
# 					]
# 				]
# 			]
# 		]
# 		[ Assign
# 			[ Name
# 				[ content ]
# 			]
# 			[ Call
# 				[ func
# 					[ Attribute
# 						[ Name
# 							[ Content ]
# 						]
# 						[ resolve_from_text ]
# 					]
# 				]
# 				[ arg
# 					[ Constant
# 						[ str
# 							[ I have a meeting at 3pm ]
# 						]
# 					]
# 				]
# 			]
# 		]
# 		[ Assign
# 			[ Name
# 				[ reminders ]
# 			]
# 			[ Call
# 				[ func
# 					[ Attribute
# 						[ Name
# 							[ Reminders ]
# 						]
# 						[ find_reminders ]
# 					]
# 				]
# 				[ keyword
# 					[ arg
# 						[ person_reminded ]
# 					]
# 					[ Name
# 						[ person_reminded ]
# 					]
# 				]
# 				[ keyword
# 					[ arg
# 						[ content ]
# 					]
# 					[ Name
# ...

# %%
df2 = pd.read_csv('../build/train_complex_utterance_to_code_with_intermediate_40k.csv.gz')
df2
# Out:
#                                                     text
# 0      see if find my first reminders that I have a m...  \
# 1      create a reminder at mindnight to close the wi...
# 2      show route to my office from Northern Mariana ...
# 3      show me how long will it take me to arrive to ...
# 4      if not look for all Pringles that are on sale ...
# ...                                                  ...
# 39995  show if what is the weather forecast on Monday...
# 39996          show directions to my office at mindnight
# 39997  get the last three messages and create on my w...
# 39998  see if report on the weather report at 11 PM i...
# 39999  find all messages from Thursday that are from ...
#
#                                                     code
# 0      person_reminded = Contact.resolve_from_text("m...  \
# 1      date_time = DateTime.resolve_from_text("mindni...
# 2      origin = Location.resolve_from_text("from Nort...
# ...
